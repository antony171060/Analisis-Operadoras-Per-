# %%
#Descargar excel desde link de Drive
# !gdown --id 1s9jAV8BDz3eUo8sV9R0pmXEQbTurf-gd

# %%
import pandas as pd

# %%
data = pd.read_excel("Data-Osiptel.xlsx", sheet_name="Telefonica")
data.head(2)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0    1    9                                           0.0
# 1    1   10                                           0.0
#
#    N° total de horas de atención al mes  CSA%  \
# 0                                8529.0   0.0
# 1                               26209.5   0.0
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                               4370
# 1                                              26101
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                  99252  0.044029
# 1                                 596323  0.043770
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                         88128
# 1                                        326554
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS  CAT (%)  Reclamos  Bajas  Consultas  Altas
# 0                         1677328   0.0525      0.76   0.79       0.78   0.95
# ...

# %%
describe_data = data.describe()
describe_data.to_excel('Telefonica.xlsx')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr_df = data.corr(method='pearson')

plt.figure(figsize=(26, 15), dpi=80)
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
data = pd.read_excel("Data-Osiptel.xlsx", sheet_name="Claro")
data.head(2)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0    1    9                                         15.12
# 1    1   10                                         26.37
#
#    N° total de horas de atención al mes      CSA%  \
# 0                               18518.0  0.000817
# 1                               18591.5  0.001418
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                            41584.0
# 1                                            37908.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES  DAP (%)  \
# 0                               493360.0   0.0843
# 1                               506790.0   0.0748
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                      118385.0
# 1                                      123382.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS  CAT (%)  Reclamos   Bajas  Consultas  \
# 0                       3124089.0   0.0379    0.6390  0.6217     0.6588
# ...

# %%
describe_data = data.describe()
describe_data.to_excel('Claro.xlsx')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr_df = data.corr(method='pearson')

plt.figure(figsize=(26, 15), dpi=80)
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
data = pd.read_excel("Data-Osiptel.xlsx", sheet_name="Entel")
data.head(2)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0    1    9                                      6.433333
# 1    1   10                                      2.166667
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
# 1                                9807.0  0.000221
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
# 1                                            16910.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
# 1                                84763.0  0.199497
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                       50182.0
# 1                                       21615.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)  Reclamos     Bajas  Consultas  \
# 0                        338717.0  0.148153  0.631699  0.715072   0.656096
# ...

# %%
describe_data = data.describe()
describe_data.to_excel('Entel.xlsx')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

corr_df = data.corr(method='pearson')

plt.figure(figsize=(26, 15), dpi=80)
sns.heatmap(corr_df, annot=True)
plt.show()

# %%
l_X = data['N° total de horas de atención al mes'].values
l_X
# Out:
# array([ 9429. ,  9807. ,  9292.5,  9526.5,  9680.5,  8998. ,  9868. ,
#         9767. ,  9485. ,  9473.5,  9473.5, 11079.5, 11195. , 11151.5,
#        10883.5, 11195. , 10926. , 11048.5, 11933.5, 11327.5, 11651. ,
#        11208.5, 10922.5, 11651. , 11651. , 11651. , 11495. , 11783. ,
#        11647. , 11937.5, 11937.5, 11937.5, 11937.5, 11937.5, 11937.5,
#        11647. , 11340.5,     nan,     nan, 10911.5, 11647. ,  7796. ,
#         8143.5,  7948. ])

# %%
plt.figure(figsize=(15, 10), dpi=80)
plt.plot(l_X, '-o', color="red")
