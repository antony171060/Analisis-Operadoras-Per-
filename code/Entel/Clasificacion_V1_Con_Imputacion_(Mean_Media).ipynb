# %%
# !pip uninstall scikit-learn
# !pip install scikit-learn==0.24.2
# Out:
# Found existing installation: scikit-learn 1.0.2
# Uninstalling scikit-learn-1.0.2:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/scikit_learn-1.0.2.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/scikit_learn.libs/libgomp-a34b3233.so.1.0.0
#     /usr/local/lib/python3.7/dist-packages/sklearn/*
# Proceed (y/n)? y
#   Successfully uninstalled scikit-learn-1.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 4.0 MB/s
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (3.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.1.0)
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.4 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed scikit-learn-0.24.2

# %% [markdown]
# ##Preprocesamiento - Data

# %% [markdown]
# ##Data

# %%
#Descargar excel desde link de Drive
# !gdown --id text

# %%
import pandas as pd

# %%
data = pd.read_excel("Data-Osiptel.xlsx", sheet_name="Entel")
data.head(5)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0    1    9                                      6.433333
# 1    1   10                                      2.166667
# 2    1   11                                      3.566667
# 3    1   12                                      3.500000
# 4    1    1                                     16.183333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
# 1                                9807.0  0.000221
# 2                                9292.5  0.000384
# 3                                9526.5  0.000367
# 4                                9680.5  0.001672
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
# 1                                            16910.0
# 2                                            16863.0
# 3                                            11868.0
# 4                                            10389.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
# 1                                84763.0  0.199497
# 2                                86335.0  0.195321
# 3                                74383.0  0.159553
# 4                                72254.0  0.143784
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                       50182.0
# 1                                       21615.0
# 2                                       30124.0
# 3                                       21069.0
# 4                                       19867.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)  Reclamos     Bajas  Consultas  \
# 0                        338717.0  0.148153  0.631699  0.715072   0.656096
# 1                        644556.0  0.033535  0.410101  0.468876   0.448331
# 2                        539400.0  0.055847  0.377196  0.437500   0.438256
# 3                        582133.0  0.036193  0.448555  0.541643   0.548162
# 4                        492719.0  0.040321  0.468233  0.515502   0.563666
#
#       Altas
# 0  0.808229
# 1  0.527333
# 2  0.623783
# 3  0.750687
# 4  0.762664

# %%
#IMPUTACION
from sklearn.impute import SimpleImputer
simple = SimpleImputer().fit(data)
df_imputed = simple.transform(data)
df_imputed = pd.DataFrame(df_imputed, columns=data.columns)
data = df_imputed
data
# Out:
#     AÑO   Mes  N° de horas sin sistema de atención al mes    \
# 0   1.0   9.0                                      6.433333
# 1   1.0  10.0                                      2.166667
# 2   1.0  11.0                                      3.566667
# 3   1.0  12.0                                      3.500000
# 4   1.0   1.0                                     16.183333
# 5   1.0   2.0                                     29.716667
# 6   1.0   3.0                                      1.233333
# 7   1.0   4.0                                      0.000000
# 8   1.0   5.0                                      0.000000
# 9   1.0   6.0                                      5.650000
# 10  1.0   7.0                                     13.550000
# 11  1.0   8.0                                     13.200000
# 12  2.0   9.0                                      3.650000
# 13  2.0  10.0                                     25.566667
# 14  2.0  11.0                                     26.200000
# 15  2.0  12.0                                      3.650000
# 16  2.0   1.0                                      8.550000
# 17  2.0   2.0                                      2.450000
# 18  2.0   3.0                                      2.916667
# 19  2.0   4.0                                      7.200000
# 20  2.0   5.0                                      8.450000
#     Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)  Reclamos     Bajas  Consultas  \
# 0                     338717.00000  0.148153  0.631699  0.715072   0.656096
# 1                     644556.00000  0.033535  0.410101  0.468876   0.448331
# 2                     539400.00000  0.055847  0.377196  0.437500   0.438256
# 3                     582133.00000  0.036193  0.448555  0.541643   0.548162
# 4                     492719.00000  0.040321  0.468233  0.515502   0.563666
# 5                     607591.00000  0.025586  0.459780  0.464623   0.568765
# 6                     673615.00000  0.023184  0.479005  0.478818   0.553953
# 7                     652977.00000  0.021629  0.465691  0.517429   0.505489
# 8                     643427.00000  0.021873  0.502797  0.530924   0.545836
# 9                     600422.00000  0.022256  0.534981  0.510960   0.573241
# 10                    627107.00000  0.028432  0.615804  0.620986   0.631460
# 11                    705167.00000  0.015802  0.563170  0.557408   0.579453
# 12                    728733.00000  0.012852  0.495330  0.496501   0.563044
# 13                    833348.00000  0.010429  0.543193  0.539575   0.580417
# 14                    824329.00000  0.010013  0.529268  0.519534   0.573255
# 15                    728733.00000  0.012852  0.495330  0.496501   0.563044
# 16                    753705.00000  0.020029  0.555169  0.577301   0.604215
# 17                    711570.00000  0.030646  0.554207  0.587491   0.601625
# 18                    743322.00000  0.027904  0.627927  0.613716   0.657771
# 19                    724338.00000  0.030345  0.589407  0.568993   0.622653
# 20                    749060.00000  0.042222  0.601727  0.541234   0.620197
# 21                    717125.00000  0.036570  0.582836  0.551136   0.655491
# 22                    750059.00000  0.036958  0.568421  0.522046   0.595398
# 23                    863904.00000  0.035893  0.547166  0.476125   0.581253
# 24                    829122.00000  0.031629  0.634547  0.553491   0.669473
# 25                    787734.00000  0.028907  0.716680  0.666408   0.746599
# 26                    801422.00000  0.029542  0.787015  0.783848   0.815351
# 27                    855474.00000  0.029722  0.720719  0.722326   0.746339
# 28                    846245.00000  0.032324  0.733620  0.720971   0.760398
# 29                    779991.00000  0.032306  0.832352  0.732130   0.790221
# 30                    841070.00000  0.038480  0.758600  0.745641   0.810106
# 31                    785477.00000  0.048876  0.773094  0.758017   0.796854
# 32                    889714.00000  0.035044  0.761682  0.734771   0.800525
# 33                    831701.00000  0.033958  0.752563  0.711588   0.819931
# 34                    881653.00000  0.033590  0.693252  0.738069   0.750595
# 35                    920062.00000  0.031653  0.767544  0.826540   0.791159
# 36                    833695.00000  0.036125  0.820102  0.812386   0.849048
# 37                    745926.52381  0.032463  0.625928  0.624246   0.666297
# 38                    745926.52381  0.032463  0.625928  0.624246   0.666297
# 39                    973143.00000  0.031224  0.749471  0.745242   0.769407
# 40                    867100.00000  0.029859  0.794816  0.790859   0.814338
# 41                    779504.00000  0.031963  0.775907  0.768500   0.804085
# 42                    808844.00000  0.029132  0.811104  0.813583   0.824838
# 43                    780906.00000  0.019582  0.758904  0.744084   0.794145
#
#        Altas
# 0   0.808229
# 1   0.527333
# 2   0.623783
# 3   0.750687
# 4   0.762664
# 5   0.791793
# 6   0.792965
# 7   0.819660
# 8   0.814852
# 9   0.828891
# 10  0.821570
# 11  0.802263
# 12  0.802889
# 13  0.791845
# 14  0.788873
# 15  0.802889
# 16  0.784874
# 17  0.783871
# 18  0.865575
# 19  0.820420
# 20  0.838996
# 21  0.855585
# 22  0.836158
# 23  0.812659
# 24  0.854301
# 25  0.870173
# 26  0.882432
# 27  0.843995
# 28  0.828831
# 29  0.735316
# 30  0.859791
# 31  0.845038
# 32  0.854405
# 33  0.899706
# 34  0.847228
# 35  0.835480
# 36  0.884192
# 37  0.816958
# 38  0.816958
# 39  0.864368
# 40  0.886270
# 41  0.880270
# 42  0.866770
# 43  0.844356

# %%
data["Reclamos"]
# Out:
# 0     0.631699
# 1     0.410101
# 2     0.377196
# 3     0.448555
# 4     0.468233
# 5     0.459780
# 6     0.479005
# 7     0.465691
# 8     0.502797
# 9     0.534981
# 10    0.615804
# 11    0.563170
# 12    0.495330
# 13    0.543193
# 14    0.529268
# 15    0.495330
# 16    0.555169
# 17    0.554207
# 18    0.627927
# 19    0.589407
# 20    0.601727
# 21    0.582836
# 22    0.568421
# 23    0.547166
# 24    0.634547
# 25    0.716680
# 26    0.787015
# 27    0.720719
# 28    0.733620
# 29    0.832352
# 30    0.758600
# 31    0.773094
# 32    0.761682
# 33    0.752563
# 34    0.693252
# 35    0.767544
# 36    0.820102
# 37    0.625928
# 38    0.625928
# 39    0.749471
# 40    0.794816
# 41    0.775907
# 42    0.811104
# 43    0.758904
# Name: Reclamos, dtype: float64

# %%
bins = [0.00, 0.20, 0.40, 0.60, 0.80, 1.0]
names = ["1", "2", "3", "4", "5"]

# %%
data["Reclamos-Cat"] = pd.cut(data["Reclamos"], bins, labels = names)
data[["Reclamos", "Reclamos-Cat"]].head(5)
# Out:
#    Reclamos Reclamos-Cat
# 0  0.631699            4
# 1  0.410101            3
# 2  0.377196            2
# 3  0.448555            3
# 4  0.468233            3

# %%
data = data.drop(['Reclamos'], axis=1)
data.head(5)
# Out:
#    AÑO   Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0   9.0                                      6.433333
# 1  1.0  10.0                                      2.166667
# 2  1.0  11.0                                      3.566667
# 3  1.0  12.0                                      3.500000
# 4  1.0   1.0                                     16.183333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
# 1                                9807.0  0.000221
# 2                                9292.5  0.000384
# 3                                9526.5  0.000367
# 4                                9680.5  0.001672
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
# 1                                            16910.0
# 2                                            16863.0
# 3                                            11868.0
# 4                                            10389.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
# 1                                84763.0  0.199497
# 2                                86335.0  0.195321
# 3                                74383.0  0.159553
# 4                                72254.0  0.143784
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                       50182.0
# 1                                       21615.0
# 2                                       30124.0
# 3                                       21069.0
# 4                                       19867.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)     Bajas  Consultas     Altas  \
# 0                        338717.0  0.148153  0.715072   0.656096  0.808229
# 1                        644556.0  0.033535  0.468876   0.448331  0.527333
# 2                        539400.0  0.055847  0.437500   0.438256  0.623783
# 3                        582133.0  0.036193  0.541643   0.548162  0.750687
# 4                        492719.0  0.040321  0.515502   0.563666  0.762664
#
#   Reclamos-Cat
# 0            4
# 1            3
# 2            2
# 3            3
# 4            3

# %%
data["Reclamos-Cat"].value_counts().sort_index()
# Out:
# 1     0
# 2     1
# 3    19
# 4    21
# 5     3
# Name: Reclamos-Cat, dtype: int64

# %% [markdown]
# #XGboost - Shrinkage (alpha - lambda)

# %% [markdown]
# ##XGBoost - Solo

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                       50182.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)     Bajas  Consultas     Altas
# 0                        338717.0  0.148153  0.715072   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=0, reg_lambda=0)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob', reg_lambda=0)

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75

# %% [markdown]
# ##XGBoost - Lasso

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                       50182.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)     Bajas  Consultas     Altas
# 0                        338717.0  0.148153  0.715072   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=1, reg_lambda=0)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob', reg_alpha=1, reg_lambda=0)

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75

# %% [markdown]
# ##XGBoost - Ridge

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                       50182.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)     Bajas  Consultas     Altas
# 0                        338717.0  0.148153  0.715072   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=0, reg_lambda=1)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75

# %% [markdown]
# ##XGBoost - Elasticnet

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO  \
# 0                                       50182.0
#
#    Nº TOTAL DE LLAMADAS ATENDIDAS   CAT (%)     Bajas  Consultas     Altas
# 0                        338717.0  0.148153  0.715072   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=1, reg_lambda=1)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob', reg_alpha=1)

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75

# %% [markdown]
# #XGboost - Con RFE

# %% [markdown]
# ##RFE

# %%
from sklearn import linear_model
from time import time
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

df = data.dropna()
X = df.drop(['Reclamos-Cat'], axis=1)
Y = df['Reclamos-Cat']

#######################################
#no of features
nof_list=np.arange(1,14)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
#########################################
cols = list(X.columns)
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 13)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,Y)  
#Fitting the data to model
model.fit(X_rfe,Y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Optimum number of features: 13
# Score with 13 features: 0.544633
# Index(['AÑO', 'Mes', 'N° de horas sin sistema de atención al mes  ',
#        'N° total de horas de atención al mes', 'CSA%',
#        'Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES',
#        'Nº TOTAL DE USUARIOS ATENDIDOS AL MES', 'DAP (%)',
#        'Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO', 'CAT (%)', 'Bajas',
#        'Consultas', 'Altas'],
#       dtype='object')
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=1 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=2 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=3 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=4 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=5 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=6 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=7 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=8 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=9 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=10 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=11 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=12 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=13 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:72: FutureWarning: Pass n_features_to_select=13 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %%
"""
Variable Eliminada:

Nº TOTAL DE LLAMADAS ATENDIDAS
"""
# Out:
# '\nVariable Eliminada:\n\nNº TOTAL DE LLAMADAS ATENDIDAS\n'

# %% [markdown]
# ##XGBoost - Solo

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat', 'Nº TOTAL DE LLAMADAS ATENDIDAS'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO   CAT (%)     Bajas  \
# 0                                       50182.0  0.148153  0.715072
#
#    Consultas     Altas
# 0   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=0, reg_lambda=0)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob', reg_lambda=0)

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75

# %% [markdown]
# ##XGBoost - Lasso

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat', 'Nº TOTAL DE LLAMADAS ATENDIDAS'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO   CAT (%)     Bajas  \
# 0                                       50182.0  0.148153  0.715072
#
#    Consultas     Altas
# 0   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=1, reg_lambda=0)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob', reg_alpha=1, reg_lambda=0)

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75

# %% [markdown]
# ##XGBoost - Ridge

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat', 'Nº TOTAL DE LLAMADAS ATENDIDAS'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO   CAT (%)     Bajas  \
# 0                                       50182.0  0.148153  0.715072
#
#    Consultas     Altas
# 0   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=0, reg_lambda=1)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75

# %% [markdown]
# ##XGBoost - Elasticnet

# %%
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = data.dropna()

# %%
X = df.drop(['Reclamos-Cat', 'Nº TOTAL DE LLAMADAS ATENDIDAS'], axis=1)
Y = df['Reclamos-Cat']

# %%
X.head(1)
# Out:
#    AÑO  Mes  N° de horas sin sistema de atención al mes    \
# 0  1.0  9.0                                      6.433333
#
#    N° total de horas de atención al mes      CSA%  \
# 0                                9429.0  0.000682
#
#    Nº DE USUARIOS QUE DESISTIERON DE LA ATENCIÓN AL MES  \
# 0                                             4989.0
#
#    Nº TOTAL DE USUARIOS ATENDIDOS AL MES   DAP (%)  \
# 0                                51894.0  0.096138
#
#    Nº DE LLAMADAS NO FINALIZADAS POR EL USUARIO   CAT (%)     Bajas  \
# 0                                       50182.0  0.148153  0.715072
#
#    Consultas     Altas
# 0   0.656096  0.808229

# %%
Y.head(2)
# Out:
# 0    4
# 1    3
# Name: Reclamos-Cat, dtype: category
# Categories (5, object): ['1' < '2' < '3' < '4' < '5']

# %%
seed = 7
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
model = XGBClassifier(reg_alpha=1, reg_lambda=1)
model.fit(X_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob', reg_alpha=1)

# %%
from sklearn import metrics
from sklearn.metrics import *

#Realizo la predicción
y_pred = model.predict(X_test)
#Verifico la matriz de Confusión
matriz = confusion_matrix(y_test, y_pred)
#Calculo la precisión del modelo
precision = precision_score(y_test, y_pred, average="macro")
#Calculo la exactitud del modelo
exactitud = accuracy_score(y_test, y_pred)
#Calculo la sensibilidad del modelo
sensibilidad = recall_score(y_test, y_pred, average="macro")
#Calculo el Puntaje F1 del modelo
puntajef1 = f1_score(y_test, y_pred, average="macro")
#Calculo la curva ROC - AUC del modelo
roc_auc = roc_auc_score(y_test, y_pred)

print('Matriz de Confusión:')
print(matriz)
print('Precisión del modelo:', precision)
print('Exactitud del modelo:', exactitud)
print('Sensibilidad del modelo:', sensibilidad)
print('Puntaje F1 del modelo:', puntajef1)
print('Curva ROC - AUC del modelo:', roc_auc)
# Out:
# Matriz de Confusión:
# [[5 0]
#  [2 2]]
# Precisión del modelo: 0.8571428571428572
# Exactitud del modelo: 0.7777777777777778
# Sensibilidad del modelo: 0.75
# Puntaje F1 del modelo: 0.75
# Curva ROC - AUC del modelo: 0.75
